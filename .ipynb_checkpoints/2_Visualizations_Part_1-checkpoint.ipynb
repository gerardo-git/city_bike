# %% [markdown]
# ## Visualizations - Part 1

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.0'

# %%
matplotlib.rcParams['agg.path.chunksize'] = 20000  # Adjusting plot parametes

# %%
matplotlib.rcParams['path.simplify_threshold'] = 0.05  # Lowering threshold value

# %%
df = pd.read_csv('ny_city_data.csv', index_col = 0)
# Out:
# C:\Users\gerar\AppData\Local\Temp\ipykernel_15304\1088745411.py:1: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('ny_city_data.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp', '_merge'],
#       dtype='object')

# %%
df.drop(columns = {'_merge'}, inplace = True)

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  5939EAFD418B83A3   classic_bike  2022-11-12 09:30:25.386
# 1  946E2F4543A846E8  electric_bike  2022-03-25 09:03:52.290
# 2  34965AE25EFC40EE  electric_bike  2022-06-26 23:01:45.341
# 3  1B8AB98865546998   classic_bike  2022-06-09 21:27:03.655
# 4  0F56BA7BA0C7ABCD   classic_bike  2022-09-27 08:50:58.155
#
#                   ended_at       start_station_name start_station_id  \
# 0  2022-11-12 09:55:09.841  South St & Whitehall St          4846.01
# 1  2022-03-25 09:12:24.679  Grand St & Havemeyer St          5267.08
# 2  2022-06-26 23:03:39.821    Popham Ave & W 174 St          8348.02
# 3  2022-06-09 21:34:29.402          W 17 St & 8 Ave          6148.02
# 4  2022-09-27 08:58:43.278       E 11 St & Avenue B          5659.11
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0          South St & Pike St        5159.07  40.701221 -74.012342  40.709918
# 1  Scholes St & Manhattan Ave        5108.01  40.712868 -73.956981  40.708704
# 2  University Ave & Brandt Pl        8366.07  40.847601 -73.922122  40.848354
# 3            10 Ave & W 28 St        6459.04  40.741776 -74.001497  40.750664
# 4     University Pl & E 14 St        5905.14  40.727464 -73.979504  40.734814
#
#      end_lng member_casual        date  avgTemp
# 0 -73.991611        casual  2022-11-12     19.7
# 1 -73.944862        member  2022-03-25      9.6
# 2 -73.918389        member  2022-06-26     27.0
# 3 -74.001768        casual  2022-06-09     24.4
# 4 -73.992085        member  2022-09-27     19.7

# %%
df.shape
# Out:
# (298388, 15)

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# date                   object
# avgTemp               float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# dtype: object

# %% [markdown]
# ### Basic plotting with pandas

# %%
df_temp = df.set_index('date')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type               started_at  \
# date
# 2022-11-12  5939EAFD418B83A3   classic_bike  2022-11-12 09:30:25.386
# 2022-03-25  946E2F4543A846E8  electric_bike  2022-03-25 09:03:52.290
# 2022-06-26  34965AE25EFC40EE  electric_bike  2022-06-26 23:01:45.341
# 2022-06-09  1B8AB98865546998   classic_bike  2022-06-09 21:27:03.655
# 2022-09-27  0F56BA7BA0C7ABCD   classic_bike  2022-09-27 08:50:58.155
#
#                            ended_at       start_station_name start_station_id  \
# date
# 2022-11-12  2022-11-12 09:55:09.841  South St & Whitehall St          4846.01
# 2022-03-25  2022-03-25 09:12:24.679  Grand St & Havemeyer St          5267.08
# 2022-06-26  2022-06-26 23:03:39.821    Popham Ave & W 174 St          8348.02
# 2022-06-09  2022-06-09 21:34:29.402          W 17 St & 8 Ave          6148.02
# 2022-09-27  2022-09-27 08:58:43.278       E 11 St & Avenue B          5659.11
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# date
# 2022-11-12          South St & Pike St        5159.07  40.701221 -74.012342
# 2022-03-25  Scholes St & Manhattan Ave        5108.01  40.712868 -73.956981
# 2022-06-26  University Ave & Brandt Pl        8366.07  40.847601 -73.922122
# 2022-06-09            10 Ave & W 28 St        6459.04  40.741776 -74.001497
# 2022-09-27     University Pl & E 14 St        5905.14  40.727464 -73.979504
#
#               end_lat    end_lng member_casual  avgTemp
# date
# 2022-11-12  40.709918 -73.991611        casual     19.7
# 2022-03-25  40.708704 -73.944862        member      9.6
# 2022-06-26  40.848354 -73.918389        member     27.0
# 2022-06-09  40.750664 -74.001768        casual     24.4
# 2022-09-27  40.734814 -73.992085        member     19.7

# %% [markdown]
# ### Procedural approach

# %%
df_temp_sorted = df_temp.sort_index()

# %%
plt.plot(df_temp_sorted['avgTemp'])
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.title('Temperatures daily for 2018')
plt.plot(df_temp_sorted['avgTemp'])
plt.show()

# %%
plt.title('Temperatures daily for 2018')
plt.figure(figsize=(10,4))
plt.plot(df_temp_sorted['avgTemp'])
plt.show()

# %% [markdown]
# ### Aggregate trips

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp'],
#       dtype='object')

# %%
# Groupby the count of the trips 

df_group = pd.DataFrame(df.groupby(['date'])['ride_id'].count()).reset_index()

# %%
df_group.head()
# Out:
#         date  ride_id
# 0 2021-11-13        1
# 1 2021-12-31        5
# 2 2022-01-01      213
# 3 2022-01-02      432
# 4 2022-01-03      349

# %%
df_group.rename(columns = {'ride_id':'bike_rides_daily'}, inplace = True)
df = df.merge(df_group, on = "date", how = 'outer', indicator = True)
print(df['_merge'].value_counts(dropna = False))
print("Shape of January 1st is", df[df['date'] == '2018-01-01'].shape) # Check 
print("Shape of January 2nd is", df[df['date'] == '2018-01-02'].shape) # Second check 

df_temp = df.set_index('date')

print(df_temp.columns)
# Out:
# _merge
# both          298388
# left_only          0
# right_only         0
# Name: count, dtype: int64
# Shape of January 1st is (0, 17)
# Shape of January 2nd is (0, 17)
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'avgTemp', 'bike_rides_daily', '_merge'],
#       dtype='object')

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  9FD8B197264255C0   classic_bike  2021-11-13 09:40:20.587
# 1  EF9EF853F0DF2E8E   classic_bike  2021-12-31 23:03:10.359
# 2  67E5409D7339F896   classic_bike  2021-12-31 22:13:01.004
# 3  7DD4ABC3F6CD8D70  electric_bike  2021-12-31 23:53:57.847
# 4  C75A7B757A4B6A5E  electric_bike  2021-12-31 16:43:54.258
#
#                   ended_at          start_station_name start_station_id  \
# 0  2022-05-14 06:12:02.901         Henry St & Grand St          5294.04
# 1  2022-01-02 00:03:04.341             E 40 St & 5 Ave          6474.11
# 2  2022-01-01 00:32:43.216  Ft. Hamilton Pkwy & E 2 St          3280.04
# 3  2022-01-01 16:54:33.971          E 13 St & Avenue A          5779.09
# 4  2022-01-01 09:55:29.503              58 St & Pier 4          3220.01
#
#              end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0     Townsend Ave & E 175 St        8323.05  40.714211 -73.981095  40.847410
# 1                         NaN            NaN  40.752062 -73.981632        NaN
# 2  Ft. Hamilton Pkwy & E 2 St        3280.04  40.648005 -73.979342  40.648005
# 3              E 2 St & 2 Ave        5593.02  40.729667 -73.980680  40.725029
# 4                         NaN            NaN  40.646475 -74.026081  40.640000
#
#      end_lng member_casual       date  avgTemp  bike_rides_daily _merge
# 0 -73.911359        casual 2021-11-13      NaN                 1   both
# 1        NaN        casual 2021-12-31      NaN                 5   both
# 2 -73.979342        casual 2021-12-31      NaN                 5   both
# 3 -73.990697        member 2021-12-31      NaN                 5   both
# 4 -74.020000        member 2021-12-31      NaN                 5   both

# %%
# Delete rows with a year 2021
df = df.loc[df['date'].dt.year != 2021]

# %%
# Reset index
df = df.reset_index(drop = True)
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  836A7ACB7EA1509C   classic_bike  2022-01-01 13:57:57.215
# 1  F26D6C68FC186BEA  electric_bike  2022-01-01 23:52:13.865
# 2  9D313B86A2A435D4  electric_bike  2022-01-01 18:06:53.687
# 3  D8F1DF07CA23408B   classic_bike  2022-01-01 16:12:09.859
# 4  278852ECDAF6DFC9  electric_bike  2022-01-01 19:18:58.289
#
#                   ended_at      start_station_name start_station_id  \
# 0  2022-01-01 14:03:00.980  University Pl & E 8 St          5755.14
# 1  2022-01-01 23:56:42.089      Water St & Main St          4936.14
# 2  2022-01-01 18:15:52.718   Carroll St & Smith St          4225.14
# 3  2022-01-01 16:14:13.249         2 Ave & E 31 St          6197.02
# 4  2022-01-01 19:27:29.446    31 Ave & Steinway St          6782.01
#
#          end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0         W 15 St & 6 Ave        5989.02  40.731437 -73.994903  40.738046
# 1  Hicks St & Montague St        4645.09  40.703212 -73.990409  40.695128
# 2            4 Ave & 3 St        4028.04  40.680611 -73.994758  40.673746
# 3         E 31 St & 3 Ave        6239.08  40.742909 -73.977061  40.743943
# 4          36 Ave & 10 St        6737.03  40.761149 -73.917007  40.761438
#
#      end_lng member_casual       date  avgTemp  bike_rides_daily _merge
# 0 -73.996430        member 2022-01-01     11.6               213   both
# 1 -73.995951        member 2022-01-01     11.6               213   both
# 2 -73.985649        member 2022-01-01     11.6               213   both
# 3 -73.979661        member 2022-01-01     11.6               213   both
# 4 -73.941126        member 2022-01-01     11.6               213   both

# %%
# Re-write data to get the correct version
df.to_csv('ny_city_data.csv')

# %%
plt.figure(figsize=(10,5))
plt.title('Temperature per trips')
plt.plot(df['avgTemp'])
plt.plot(df['bike_rides_daily'], color = 'red')
plt.show()

# %% [markdown]
# ### OO approach

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df['bike_rides_daily'],color = "red")

# %%
# Create figure and axis objects with subplots()

fig, ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df['bike_rides_daily'],color = "red")
ax.plot(df['avgTemp'], color = 'blue')

# %%
y, a = (1,2)
print(y)
print(a)
# Out:
# 1
# 2

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df['bike_rides_daily'],color = "red")

# Here is where we create the dual axis - initialize a twin object for two different y-axis on the sample plot
ax2 = ax.twinx()

# Make a plot with the temperatues on the y-axis using second axis object
ax2.plot(df["avgTemp"], color = "blue")
#plt.show()

# %% [markdown]
# #### Final dual plot

# %%
# Create figure and axis objects with subplots() and details

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df['bike_rides_daily'],color = "navy")
ax.set_xlabel("Year 2018", fontsize = 14) # set x-axis label
ax.set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Here is where we create the dual axis - initialize a twin object for two different y-axis on the sample plot
ax2 = ax.twinx()

# Make a plot with the temperatues on the y-axis using second axis object
ax2.plot(df["avgTemp"], color = "red")
ax2.set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.title('Temperature and trips in 2018', fontsize = 18)
plt.show()

# %%
plt.style.use('ggplot')

# %%
# Create figure and axis objects with subplots() and details

fig,ax = plt.subplots(2, figsize =(8, 6))

# Make a plot of the bike rides
ax[0].plot(df['bike_rides_daily'],color = "navy")
ax[0].set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Make a plot with the temperatues on the y-axis using second axis object
ax[1].plot(df_temp["avgTemp"], color = "red")
ax[1].set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.suptitle('Temperature and trips in 2018', fontsize = 18)

plt.show()

# %%
# save the plot as a file
fig.savefig('trips_temperatures_dual_line.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
